# %% [markdown]
# <a href="https://colab.research.google.com/github/NamrathaBajjuri/AIML-TRAINING-TNSIF/blob/main/EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
uploaded =files.upload()
# Out:
#      <input type="file" id="files-4fd33b9e-02fa-46cf-ab34-d29b51c36875" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4fd33b9e-02fa-46cf-ab34-d29b51c36875">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_csv("weight-height.csv")
df
# Out:
#       Gender     Height      Weight
# 0       Male  73.847017  241.893563
# 1       Male  68.781904  162.310473
# 2       Male  74.110105  212.740856
# 3       Male  71.730978  220.042470
# 4       Male  69.881796  206.349801
# ...      ...        ...         ...
# 9995  Female  66.172652  136.777454
# 9996  Female  67.067155  170.867906
# 9997  Female  63.867992  128.475319
# 9998  Female  69.034243  163.852461
# 9999  Female  61.944246  113.649103
#
# [10000 rows x 3 columns]

# %%
# Height histogram
sns.histplot(data=df, x="Height", bins=10, kde=True)

plt.title("Height Distribution")
plt.xlabel("Height")
plt.ylabel("Frequency")
plt.show()

# %%
# Weight histogram
sns.histplot(data=df, x="Weight", bins=10, kde=True)

plt.title("Weight Distribution")
plt.xlabel("Weight")
plt.ylabel("Frequency")
plt.show()

# %%
df.describe()
# Out:
#              Height        Weight
# count  10000.000000  10000.000000
# mean      66.367560    161.440357
# std        3.847528     32.108439
# min       54.263133     64.700127
# 25%       63.505620    135.818051
# 50%       66.318070    161.212928
# 75%       69.174262    187.169525
# max       78.998742    269.989699

# %%
#Detect outliers using IQR
Q1 = df.Height.quantile(0.25)
Q3 = df.Height.quantile(0.75)
Q1, Q3
# Out:
# (np.float64(63.505620481218955), np.float64(69.1742617268347))

# %%
IQR = Q3 - Q1
IQR
# Out:
# np.float64(5.668641245615746)

# %%
lower_limit = Q1 - 1.5*IQR
upper_limit = Q3 + 1.5*IQR
lower_limit, upper_limit
# Out:
# (np.float64(55.00265861279534), np.float64(77.67722359525831))

# %%
#Here are the outliers

df[(df.Height<lower_limit)|(df.Height>upper_limit)]
# Out:
#       Gender     Height      Weight
# 994     Male  78.095867  255.690835
# 1317    Male  78.462053  227.342565
# 2014    Male  78.998742  269.989699
# 3285    Male  78.528210  253.889004
# 3757    Male  78.621374  245.733783
# 6624  Female  54.616858   71.393749
# 7294  Female  54.873728   78.606670
# 9285  Female  54.263133   64.700127

# %%
# Calculate mean
mean_value = df['Height'].mean()

# Replace outliers with mean
df['Height'] = df['Height'].apply(
    lambda x: mean_value if x < lower_limit or x > upper_limit else x
)
# Print dataset
print(df)
# Out:
#       Gender     Height      Weight
# 0       Male  73.847017  241.893563
# 1       Male  68.781904  162.310473
# 2       Male  74.110105  212.740856
# 3       Male  71.730978  220.042470
# 4       Male  69.881796  206.349801
# ...      ...        ...         ...
# 9995  Female  66.172652  136.777454
# 9996  Female  67.067155  170.867906
# 9997  Female  63.867992  128.475319
# 9998  Female  69.034243  163.852461
# 9999  Female  61.944246  113.649103
#
# [10000 rows x 3 columns]

# %%
# Calculate median
median_value = df['Height'].median()

# Replace outliers with median
df['Height'] = df['Height'].apply(
    lambda x: median_value if x < lower_limit or x > upper_limit else x
)

# Print dataset
print(df)
# Out:
#       Gender     Height      Weight
# 0       Male  73.847017  241.893563
# 1       Male  68.781904  162.310473
# 2       Male  74.110105  212.740856
# 3       Male  71.730978  220.042470
# 4       Male  69.881796  206.349801
# ...      ...        ...         ...
# 9995  Female  66.172652  136.777454
# 9996  Female  67.067155  170.867906
# 9997  Female  63.867992  128.475319
# 9998  Female  69.034243  163.852461
# 9999  Female  61.944246  113.649103
#
# [10000 rows x 3 columns]

# %%
#Detect outliers using IQR
Q1 = df.Weight.quantile(0.25)
Q3 = df.Weight.quantile(0.75)
Q1, Q3
# Out:
# (np.float64(135.8180513055015), np.float64(187.16952486868348))

# %%
IQR = Q3 - Q1
IQR
# Out:
# np.float64(51.35147356318197)

# %%
lower_limit = Q1 - 1.5*IQR
upper_limit = Q3 + 1.5*IQR
lower_limit, upper_limit
# Out:
# (np.float64(58.79084096072856), np.float64(264.19673521345646))

# %%
#Here are the outliers

df[(df.Weight<lower_limit)|(df.Weight>upper_limit)]
# Out:
#      Gender    Height      Weight
# 2014   Male  66.36756  269.989699

# %%
# Calculate mean
mean_value = df['Weight'].mean()

# Replace outliers with mean
df['Weight'] = df['Weight'].apply(
    lambda x: mean_value if x < lower_limit or x > upper_limit else x
)
# Print dataset
print(df)
# Out:
#       Gender     Height      Weight
# 0       Male  73.847017  241.893563
# 1       Male  68.781904  162.310473
# 2       Male  74.110105  212.740856
# 3       Male  71.730978  220.042470
# 4       Male  69.881796  206.349801
# ...      ...        ...         ...
# 9995  Female  66.172652  136.777454
# 9996  Female  67.067155  170.867906
# 9997  Female  63.867992  128.475319
# 9998  Female  69.034243  163.852461
# 9999  Female  61.944246  113.649103
#
# [10000 rows x 3 columns]

# %%
# Calculate median
median_value = df['Weight'].median()

# Replace outliers with median
df['Weight'] = df['Weight'].apply(
    lambda x: median_value if x < lower_limit or x > upper_limit else x
)

# Print dataset
print(df)
# Out:
#       Gender     Height      Weight
# 0       Male  73.847017  241.893563
# 1       Male  68.781904  162.310473
# 2       Male  74.110105  212.740856
# 3       Male  71.730978  220.042470
# 4       Male  69.881796  206.349801
# ...      ...        ...         ...
# 9995  Female  66.172652  136.777454
# 9996  Female  67.067155  170.867906
# 9997  Female  63.867992  128.475319
# 9998  Female  69.034243  163.852461
# 9999  Female  61.944246  113.649103
#
# [10000 rows x 3 columns]
